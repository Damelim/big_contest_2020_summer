# %% [markdown]
# ### 피타고리안 승률 위해선 득점 / 실점의 예상치 필요
#
# #### 1. 실점 => kwERA 이용해 추정
#
#            => 팀 방어율 예측할 때도 가능할 듯
#
# #### 2. 득점 => XR 이용해 추정

# %% [markdown]
# - XR = { (HIT-H2-H3-HR) * 0.5 + H2 * 0.72 + H3 * 1.04 + HR * 1.44 + (HBP+BB-IB) * 0.34 + IB * 0.25 + SB * 0.18 - CS * 0.32 - (AB-HIT-KK) * 0.09 - KK * 0.098 - GD * 0.37 + SF * 0.37 + SH * 0.04 }

# %% [markdown]
# - XR 사용 위해선 안타 수를 예측해야 함 (홈런, 2루타 포함한)
#
#     => 삼진 볼넷 이런 것들은 지금까지 기록한 것과 비슷하게 기록할 것이라는 전제

# %% [markdown]
# - 안타를 제외한 다른 지표로 안타 수 / 타율 예측하려면.....?

# %% [markdown]
# ### 2-1) Marcel
#
# - 성적 예측 시스템의 기틀
#
# - 간단한 계산으로 꽤 정확한 예측을 가능하게 함
#
# ![image.png](attachment:image.png)

# %% [markdown]
# - 실제 적용 결과 (예시)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# - 랜덤 포레스트로 예측하는 것이 오차가 더 적다고 하지만 우리가 얻지 못하는 데이터를 필요로 함
#
# https://yagongso.com/?p=9317

# %% [markdown]
# ### 2-2) 타율 예측 이론(?)
#
# ![image.png](attachment:image.png)
#
# - SO : 삼진
# - HR : 홈런
# - HIP: hit-in-play (삼진을 제외하고 방망이에 공이 맞은 경우를 의미하는 듯?)
# - #### 전부 확률이므로 타석 또는 타수로 나눠줘야 함

# %% [markdown]
# #### 출처: https://www.stat.sfu.ca/content/dam/sfu/stat/alumnitheses/2017/1177SarahBaileyThesis.pdf

# %% [markdown]
# ### 투수 보다 타자가 더 어려워 보임...
