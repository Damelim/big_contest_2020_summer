# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
game_2016 = pd.read_csv('data\game_2016.csv', encoding='CP949')
players_2016 = pd.read_csv('data\players_2016.csv', encoding='CP949')
registered_players_2016 = pd.read_csv('data\\registered_players_2016.csv', encoding='CP949')
private_batter_2016 = pd.read_csv('data\private_batter_2016.csv', encoding='CP949')
private_pitcher_2016 = pd.read_csv('data\private_pitcher_2016.csv',encoding='CP949')
team_2016 = pd.read_csv('data\\team_2016.csv',encoding='CP949')
team_batter_2016 = pd.read_csv('data\\team_batter_2016.csv',encoding='CP949')
team_pitcher_2016 = pd.read_csv('data\\team_pitcher_2016.csv',encoding='CP949')

# %% [markdown]
# ## 예측해야 하는 것
#
# 1. 타율 : 안타수(홈런)/타수
# 타수는 희생번트, 희생플라이, 4구, 사구, 방해에 의해 1루 나간 경우 제외
#
# 2. 방어율 : 자책점*9 / 투구이닝수 > 수비실책에 의한 실점은 제외한 자책점
# ex 9이닝동안 몇점을 내주느냐
# 7이닝동안 1실점을 한경우 >> 9/7 = 1.29
#
# 3. 승률

# %% [markdown]
# #### 홀드 : 초말 선수가 아닌 구원투수의 실적을 나타내는 용어 중 하나
# 1. 3점이하의 리드시 등판하여 최소 1이닝(3아웃)을 막아주는 경우.
# 2. 점수차와 관계없이 리드시 최저 3이닝을 던져 리드를 지켜준 경우.
# 3. 백투백홈런(두 타자 연속홈런)을 맞으면 동점이 되는 상황에서 아웃 카운트 하나 이상을 올려준 경우.
#
# #### 타수: 타자가 타석에 들어가서 타격을 완료한 횟수
# 희생 번프, 타격방해, 스트라이크 볼은 타수에 해당되지 않는다
#
# #### 폭투: 투수가 공을 던졌을 때 포수가 공을 바로 잡지 못하는 경우.. 포수의 실수이거나 투수가 공을 너무 거칠게 던져서 발생
#
# #### 보크: 반칙 투구 행위

# %% [markdown]
# ## 경기

# %%
game_2016.head()
# Out:
#             G_ID   GDAY_DS VISIT_KEY HOME_KEY  HEADER_NO GWEEK STADIUM
# 0  20160401HHLG0  20160401        HH       LG          0     금      잠실
# 1  20160401HTNC0  20160401        HT       NC          0     금      마산
# 2  20160401KTSK0  20160401        KT       SK          0     금      문학
# 3  20160401LTWO0  20160401        LT       WO          0     금      고척
# 4  20160401OBSS0  20160401        OB       SS          0     금      대구

# %% [markdown]
# - 게임키 / 일자 / 원정팀코드 / 홈팀코드 / 더블헤더코드(0-일반경기,1-더블헤더1차전,2-더블헤더2차전)/ 요일 / 구장(경기치러가는구장)

# %% [markdown]
# ## 선수

# %%
players_2016.head()
# Out:
#    GYEAR  PCODE NAME T_ID POSITION  AGE_VA   MONEY
# 0   2016  60100  백창수   LG        내      28  4000만원
# 1   2016  60105  배민관   LG        투      25  2700만원
# 2   2016  60146  이승현   LG        투      25  3700만원
# 3   2016  60164  유경국   LG        투      25  2700만원
# 4   2016  60181  김지용   LG        투      28  4000만원

# %% [markdown]
# - 시즌 / 선수코드 / 선수명 / 팀코드 / 포지션 / 나이 / 연봉

# %%
img1 = plt.imread('img\players.jpg')
plt.imshow(img1,aspect='auto')

# %%
players_2016['POSITION'].unique()
# Out:
# array(['내', '투', '포', '외'], dtype=object)

# %% [markdown]
# - 포지션 : 내야, 투수, 포수, 외야

# %% [markdown]
# ## 등록선수

# %%
registered_players_2016.head()
# Out:
#     GDAY_DS T_ID   P_ID ENTRY_YN
# 0  20160401   HH  60404        Y
# 1  20160401   HH  60667        Y
# 2  20160401   HH  60757        Y
# 3  20160401   HH  60764        N
# 4  20160401   HH  60768        N

# %% [markdown]
# - 일자(등록/말소 일자)/ 팀코드/ 선수코드/ 등록말소

# %% [markdown]
# ## 개인 타자

# %%
private_batter_2016.head().transpose()
# Out:
#                           0              1              2              3  \
# G_ID          20160401HHLG0  20160401HHLG0  20160401HHLG0  20160401HHLG0
# GDAY_DS            20160401       20160401       20160401       20160401
# T_ID                     HH             LG             LG             LG
# VS_T_ID                  LG             HH             HH             HH
# HEADER_NO                 0              0              0              0
# TB_SC                     T              B              B              B
# P_ID                  60404          61102          61186          62164
# START_CK                  0              1              1              0
# BAT_ORDER_NO              3              8              7              9
# PA                        1              3              4              1
# AB                        1              3              4              0
# RBI                       0              0              2              0
# RUN                       0              0              2              0
# HIT                       1              0              3              0
# H2                        0              0              0              0
# H3                        0              0              0              0
# HR                        0              0              1              0
# SB                        0              0              0              0
# CS                        0              0              1              0
# SH                        0              0              0              0
# SF                        0              0              0              0
# BB                        0              0              0              1
# IB                        0              0              0              0
# HP                        0              0              0              0
# KK                        0              2              1              0
# GD                        0              0              0              0
# ERR                       0              0              0              0
# LOB                       1              0              0              0
# P_HRA_RT                  0              0              1              0
# P_AB_CN                   0              0              1              0
# P_HIT_CN                  0              0              1              0
#
#                           4
# G_ID          20160401HHLG0
# GDAY_DS            20160401
# T_ID                     HH
# VS_T_ID                  LG
# HEADER_NO                 0
# TB_SC                     T
# P_ID                  62700
# START_CK                  1
# BAT_ORDER_NO              9
# PA                        2
# AB                        2
# RBI                       0
# RUN                       1
# HIT                       1
# H2                        0
# H3                        0
# HR                        0
# SB                        0
# CS                        0
# SH                        0
# SF                        0
# BB                        0
# IB                        0
# HP                        0
# KK                        0
# GD                        0
# ERR                       1
# LOB                       0
# P_HRA_RT                  0
# P_AB_CN                   0
# P_HIT_CN                  0

# %%
private_batter_2016.columns
# Out:
# Index(['G_ID', 'GDAY_DS', 'T_ID', 'VS_T_ID', 'HEADER_NO', 'TB_SC', 'P_ID',
#        'START_CK', 'BAT_ORDER_NO', 'PA', 'AB', 'RBI', 'RUN', 'HIT', 'H2', 'H3',
#        'HR', 'SB', 'CS', 'SH', 'SF', 'BB', 'IB', 'HP', 'KK', 'GD', 'ERR',
#        'LOB', 'P_HRA_RT', 'P_AB_CN', 'P_HIT_CN'],
#       dtype='object')

# %% [markdown]
# - 게임키 / 일자 / 팀코드 / 상대팀코드 / 더블헤더코드 / 초말(T-초,B-말) / 선수코드 / 선발(선발출장여부-0,1) / 타순(해당경기 출전타순) / 타자 / 타수 / 타점 / 득점 / 안타 / 2루타/ 3루타 / 홈런 / 도루 / 도루실패 / 희타 / 희비 / 4구(볼넷) / 고4(고의4구) / 사구(몸에 맞는 볼) / 삼진 / 병살타 / 실책 / 잔루(이닝이 끝난 상황에 누상에 남아있는 주자 수) / 득점권타율 / 득점권타수 / 득점권안타

# %%
private_batter_2016.groupby(['G_ID','T_ID'])['P_ID'].count().mean()
# Out:
# 12.975

# %% [markdown]
# - 한 경기당 평균적으로 12.9명의 선수가 출전한다

# %%
private_batter_2016[(private_batter_2016['G_ID']=='20160401HHLG0')&(private_batter_2016['T_ID']=='LG')].transpose()
# Out:
#                          1              2              3              5   \
# G_ID          20160401HHLG0  20160401HHLG0  20160401HHLG0  20160401HHLG0
# GDAY_DS            20160401       20160401       20160401       20160401
# T_ID                     LG             LG             LG             LG
# VS_T_ID                  HH             HH             HH             HH
# HEADER_NO                 0              0              0              0
# TB_SC                     B              B              B              B
# P_ID                  61102          61186          62164          63077
# START_CK                  1              1              0              0
# BAT_ORDER_NO              8              7              9              2
# PA                        3              4              1              0
# AB                        3              4              0              0
# RBI                       0              2              0              0
# RUN                       0              2              0              0
# HIT                       0              3              0              0
# H2                        0              0              0              0
# H3                        0              0              0              0
# HR                        0              1              0              0
# SB                        0              0              0              0
# CS                        0              1              0              0
# SH                        0              0              0              0
# SF                        0              0              0              0
# BB                        0              0              1              0
# IB                        0              0              0              0
# HP                        0              0              0              0
# KK                        2              1              0              0
# GD                        0              0              0              0
# ERR                       0              0              0              0
# LOB                       0              0              0              0
# P_HRA_RT                  0              1              0              0
# P_AB_CN                   0              1              0              0
# P_HIT_CN                  0              1              0              0
#
#                          6              8              9              10  \
# G_ID          20160401HHLG0  20160401HHLG0  20160401HHLG0  20160401HHLG0
# GDAY_DS            20160401       20160401       20160401       20160401
# T_ID                     LG             LG             LG             LG
# VS_T_ID                  HH             HH             HH             HH
# HEADER_NO                 0              0              0              0
# TB_SC                     B              B              B              B
# P_ID                  63123          64153          65103          65115
# START_CK                  1              0              1              0
# BAT_ORDER_NO              9              2              5              7
# PA                        3              1              5              1
# AB                        2              1              5              1
# RBI                       0              1              1              0
# RUN                       0              0              0              0
# HIT                       0              1              1              0
# H2                        0              1              1              0
# H3                        0              0              0              0
# HR                        0              0              0              0
# SB                        0              0              0              0
# CS                        0              0              0              0
# SH                        0              0              0              0
# SF                        0              0              0              0
# BB                        1              0              0              0
# IB                        0              0              0              0
# HP                        0              0              0              0
# KK                        1              0              0              0
# GD                        0              0              0              0
# ERR                       0              0              0              0
# LOB                       0              1              1              0
# P_HRA_RT                  0              1            0.5              0
# P_AB_CN                   0              1              2              0
# P_HIT_CN                  0              1              1              0
#
#                          15             16             19             21  \
# G_ID          20160401HHLG0  20160401HHLG0  20160401HHLG0  20160401HHLG0
# GDAY_DS            20160401       20160401       20160401       20160401
# T_ID                     LG             LG             LG             LG
# VS_T_ID                  HH             HH             HH             HH
# HEADER_NO                 0              0              0              0
# TB_SC                     B              B              B              B
# P_ID                  71842          72133          74823          76100
# START_CK                  0              1              1              1
# BAT_ORDER_NO              8              3              1              4
# PA                        2              5              6              5
# AB                        2              5              4              5
# RBI                       0              0              0              0
# RUN                       0              0              1              0
# HIT                       0              0              1              2
# H2                        0              0              0              0
# H3                        0              0              0              0
# HR                        0              0              0              0
# SB                        0              0              1              1
# CS                        0              0              0              0
# SH                        0              0              1              0
# SF                        0              0              0              0
# BB                        0              0              1              0
# IB                        0              0              0              0
# HP                        0              0              0              0
# KK                        1              0              0              2
# GD                        0              0              0              0
# ERR                       0              0              0              0
# LOB                       0              0              2              2
# P_HRA_RT                  0              0              0            0.5
# P_AB_CN                   0              3              1              2
# P_HIT_CN                  0              0              0              1
#
#                          22             23             24             25  \
# G_ID          20160401HHLG0  20160401HHLG0  20160401HHLG0  20160401HHLG0
# GDAY_DS            20160401       20160401       20160401       20160401
# T_ID                     LG             LG             LG             LG
# VS_T_ID                  HH             HH             HH             HH
# HEADER_NO                 0              0              0              0
# TB_SC                     B              B              B              B
# P_ID                  78217          79150          79192          79198
# START_CK                  0              1              0              0
# BAT_ORDER_NO              9              2              9              9
# PA                        0              5              1              0
# AB                        0              5              1              0
# RBI                       0              0              0              0
# RUN                       1              0              0              0
# HIT                       0              0              0              0
# H2                        0              0              0              0
# H3                        0              0              0              0
# HR                        0              0              0              0
# SB                        0              0              0              0
# CS                        0              0              0              0
# SH                        0              0              0              0
# SF                        0              0              0              0
# BB                        0              0              0              0
# IB                        0              0              0              0
# HP                        0              0              0              0
# KK                        0              3              0              0
# GD                        0              0              0              0
# ERR                       0              0              0              0
# LOB                       0              1              0              0
# P_HRA_RT                  0              0              0              0
# P_AB_CN                   0              1              0              0
# P_HIT_CN                  0              0              0              0
#
#                          28
# G_ID          20160401HHLG0
# GDAY_DS            20160401
# T_ID                     LG
# VS_T_ID                  HH
# HEADER_NO                 0
# TB_SC                     B
# P_ID                  99606
# START_CK                  1
# BAT_ORDER_NO              6
# PA                        5
# AB                        4
# RBI                       0
# RUN                       1
# HIT                       1
# H2                        0
# H3                        0
# HR                        0
# SB                        0
# CS                        0
# SH                        0
# SF                        0
# BB                        1
# IB                        0
# HP                        0
# KK                        1
# GD                        0
# ERR                       0
# LOB                       1
# P_HRA_RT                  0
# P_AB_CN                   1
# P_HIT_CN                  0

# %%
df1 =private_batter_2016[(private_batter_2016['G_ID']=='20160401HHLG0')&(private_batter_2016['T_ID']=='LG')]

# %% [markdown]
# - 잔루? 해당 선수가 3아웃으로 아웃되는 상황인 경우 누상에 남아있는 주자수를 의미하는가?

# %%
private_batter_2016['LOB'].unique()
# Out:
# array([1, 0, 2, 3, 4, 5], dtype=int64)

# %% [markdown]
# ## 개인 투수

# %%
private_pitcher_2016.head(5).transpose()
# Out:
#                         0              1              2              3  \
# G_ID        20160401HHLG0  20160401HHLG0  20160401HHLG0  20160401HHLG0
# GDAY_DS          20160401       20160401       20160401       20160401
# T_ID                   LG             LG             LG             LG
# VS_T_ID                HH             HH             HH             HH
# HEADER_NO               0              0              0              0
# TB_SC                   B              B              B              B
# P_ID                60146          61891          62146          62698
# START_CK                0              0              0              1
# RELIEF_CK               1              1              1              0
# CG_CK                   0              0              0              0
# QUIT_CK                 1              0              0              0
# WLS                     W
# HOLD                    0              0              0              0
# INN2                    6              5              1             18
# BF                     29             33              7             94
# PA                      8              8              2             28
# AB                      7              6              2             25
# HIT                     1              2              1              9
# H2                      0              0              0              2
# H3                      0              0              0              0
# HR                      0              0              0              0
# SB                      0              0              0              0
# CS                      0              0              0              0
# SH                      0              1              0              2
# SF                      0              0              0              0
# BB                      1              1              0              1
# IB                      0              0              0              0
# HP                      0              0              0              0
# KK                      3              1              0              4
# GD                      0              0              0              1
# WP                      0              0              0              0
# BK                      0              0              0              0
# ERR                     0              0              0              0
# R                       0              0              0              4
# ER                      0              0              0              4
# P_WHIP_RT               0              0              0       0.818182
# P2_WHIP_RT              1            1.8              3        1.58824
# CB_WHIP_RT            1.5            1.5              0           3.75
#
#                         4
# G_ID        20160401HHLG0
# GDAY_DS          20160401
# T_ID                   HH
# VS_T_ID                LG
# HEADER_NO               0
# TB_SC                   T
# P_ID                65764
# START_CK                0
# RELIEF_CK               1
# CG_CK                   0
# QUIT_CK                 1
# WLS                     L
# HOLD                    0
# INN2                    4
# BF                     27
# PA                      6
# AB                      4
# HIT                     1
# H2                      1
# H3                      0
# HR                      0
# SB                      0
# CS                      0
# SH                      1
# SF                      0
# BB                      1
# IB                      0
# HP                      0
# KK                      1
# GD                      0
# WP                      0
# BK                      0
# ERR                     0
# R                       1
# ER                      1
# P_WHIP_RT               0
# P2_WHIP_RT            1.5
# CB_WHIP_RT              0

# %%
private_pitcher_2016.columns
# Out:
# Index(['G_ID', 'GDAY_DS', 'T_ID', 'VS_T_ID', 'HEADER_NO', 'TB_SC', 'P_ID',
#        'START_CK', 'RELIEF_CK', 'CG_CK', 'QUIT_CK', 'WLS', 'HOLD', 'INN2',
#        'BF', 'PA', 'AB', 'HIT', 'H2', 'H3', 'HR', 'SB', 'CS', 'SH', 'SF', 'BB',
#        'IB', 'HP', 'KK', 'GD', 'WP', 'BK', 'ERR', 'R', 'ER', 'P_WHIP_RT',
#        'P2_WHIP_RT', 'CB_WHIP_RT'],
#       dtype='object')

# %% [markdown]
# - 게임키 / 일자 / 팀코드 / 상대팀코드 / 더블헤더코드 / 초말 / 선수코드/ 선발(0,1) / 구원(0,1) / 완투(0,1) / 종료(마지막 투수여부-0,1) / 결과(W승 L패 S세) / 홀드 / 이닝*3 /투구수 / 타자(상대타자 숫자) / 타수(상대타자 타수) / 안타/ 2루타/ 3루타/ 홈런 / 도루/ 도루실패 / 희타 / 희비 / 4구 / 고4 / 사구(몸에 맞는볼) / 삼진 / 병살타 / 폭투 / 보크 / 실책 / 실점(총실점) / 자책점(투수의 책임이 되는 실점) / 득점권 WHIP / 2점이하 WHIP/ 345번타자(WHIP)

# %%
private_pitcher_2016[(private_pitcher_2016['G_ID']=='20160401HHLG0')&(private_pitcher_2016['T_ID']=='LG')].transpose()
# Out:
#                         0              1              2              3  \
# G_ID        20160401HHLG0  20160401HHLG0  20160401HHLG0  20160401HHLG0
# GDAY_DS          20160401       20160401       20160401       20160401
# T_ID                   LG             LG             LG             LG
# VS_T_ID                HH             HH             HH             HH
# HEADER_NO               0              0              0              0
# TB_SC                   B              B              B              B
# P_ID                60146          61891          62146          62698
# START_CK                0              0              0              1
# RELIEF_CK               1              1              1              0
# CG_CK                   0              0              0              0
# QUIT_CK                 1              0              0              0
# WLS                     W
# HOLD                    0              0              0              0
# INN2                    6              5              1             18
# BF                     29             33              7             94
# PA                      8              8              2             28
# AB                      7              6              2             25
# HIT                     1              2              1              9
# H2                      0              0              0              2
# H3                      0              0              0              0
# HR                      0              0              0              0
# SB                      0              0              0              0
# CS                      0              0              0              0
# SH                      0              1              0              2
# SF                      0              0              0              0
# BB                      1              1              0              1
# IB                      0              0              0              0
# HP                      0              0              0              0
# KK                      3              1              0              4
# GD                      0              0              0              1
# WP                      0              0              0              0
# BK                      0              0              0              0
# ERR                     0              0              0              0
# R                       0              0              0              4
# ER                      0              0              0              4
# P_WHIP_RT               0              0              0       0.818182
# P2_WHIP_RT              1            1.8              3        1.58824
# CB_WHIP_RT            1.5            1.5              0           3.75
#
#                         5              6
# G_ID        20160401HHLG0  20160401HHLG0
# GDAY_DS          20160401       20160401
# T_ID                   LG             LG
# VS_T_ID                HH             HH
# HEADER_NO               0              0
# TB_SC                   B              B
# P_ID                70839          71118
# START_CK                0              0
# RELIEF_CK               1              1
# CG_CK                   0              0
# QUIT_CK                 0              0
# WLS
# HOLD                    0              0
# INN2                    3              3
# BF                     11             10
# PA                      3              3
# AB                      3              3
# HIT                     0              0
# H2                      0              0
# H3                      0              0
# HR                      0              0
# SB                      0              0
# CS                      0              0
# SH                      0              0
# SF                      0              0
# BB                      0              0
# IB                      0              0
# HP                      0              0
# KK                      1              1
# GD                      0              0
# WP                      0              0
# BK                      0              0
# ERR                     0              0
# R                       0              0
# ER                      0              0
# P_WHIP_RT               0              0
# P2_WHIP_RT              0              0
# CB_WHIP_RT              0              0

# %% [markdown]
# - 경기 결과가 한 선수의 행에만 존재해서 같은 경기를 치룬 투수들에게 동일한 값을 할당해야 함
# - INN2 이게 정확히 뭘 말하는지 모르겠음.. 3의 배수가 아닌 것이 있음

# %%
private_pitcher_2016['SH'].unique()
# Out:
# array([0, 1, 2, 3, 4], dtype=int64)

# %%
private_pitcher_2016.groupby(['G_ID','T_ID'])['P_ID'].count().mean()
# Out:
# 4.4534722222222225

# %% [markdown]
# ## 팀시트

# %%
team_2016
# Out:
#   T_ID T_NM
# 0   HH   한화
# 1   HT  KIA
# 2   KT   KT
# 3   LG   LG
# 4   LT   롯데
# 5   NC   NC
# 6   OB   두산
# 7   SK   SK
# 8   SS   삼성
# 9   WO   넥센

# %% [markdown]
# - 팀코드/팀명

# %% [markdown]
# ## 팀타자

# %%
team_batter_2016.head(5).transpose()
# Out:
#                        0              1              2              3  \
# G_ID       20160401HHLG0  20160401HHLG0  20160401HTNC0  20160401HTNC0
# GDAY_DS         20160401       20160401       20160401       20160401
# T_ID                  LG             HH             NC             HT
# VS_T_ID               HH             LG             HT             NC
# HEADER_NO              0              0              0              0
# TB_SC                  B              T              B              T
# PA                    47             52             36             38
# AB                    42             46             30             34
# RBI                    4              4              5              3
# RUN                    5              4              5              4
# HIT                    9             13              9              8
# H2                     2              2              2              3
# H3                     0              0              0              0
# HR                     1              0              2              1
# SB                     2              0              0              0
# CS                     1              0              0              0
# SH                     1              3              1              0
# SF                     0              0              0              0
# BB                     4              3              5              3
# IB                     0              0              0              0
# HP                     0              0              0              1
# KK                    11             10              9             10
# GD                     0              1              1              1
# ERR                    0              2              1              0
# LOB                    8             12              7              7
# P_HRA_RT        0.333333            0.2       0.142857            0.1
# P_AB_CN               12             15              7             10
# P_HIT_CN               4              3              1              1
#
#                        4
# G_ID       20160401KTSK0
# GDAY_DS         20160401
# T_ID                  SK
# VS_T_ID               KT
# HEADER_NO              0
# TB_SC                  B
# PA                    36
# AB                    36
# RBI                    4
# RUN                    4
# HIT                   10
# H2                     5
# H3                     0
# HR                     1
# SB                     0
# CS                     0
# SH                     0
# SF                     0
# BB                     0
# IB                     0
# HP                     0
# KK                     7
# GD                     1
# ERR                    1
# LOB                    5
# P_HRA_RT           0.375
# P_AB_CN                8
# P_HIT_CN               3

# %%
df1.sum()
# Out:
# G_ID            20160401HHLG020160401HHLG020160401HHLG02016040...
# GDAY_DS                                                 342726817
# T_ID                           LGLGLGLGLGLGLGLGLGLGLGLGLGLGLGLGLG
# VS_T_ID                        HHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHH
# HEADER_NO                                                       0
# TB_SC                                           BBBBBBBBBBBBBBBBB
# P_ID                                                      1215284
# START_CK                                                        9
# BAT_ORDER_NO                                                  100
# PA                                                             47
# AB                                                             42
# RBI                                                             4
# RUN                                                             5
# HIT                                                             9
# H2                                                              2
# H3                                                              0
# HR                                                              1
# SB                                                              2
# CS                                                              1
# SH                                                              1
# SF                                                              0
# BB                                                              4
# IB                                                              0
# HP                                                              0
# KK                                                             11
# GD                                                              0
# ERR                                                             0
# LOB                                                             8
# P_HRA_RT                                                        3
# P_AB_CN                                                        12
# P_HIT_CN                                                        4
# dtype: object

# %% [markdown]
# - 팀 기록은 개인 데이터의 값을 단순히 더한 것..

# %%
team_batter_2016[(team_batter_2016['G_ID']=='20160401HHLG0')&(team_batter_2016['T_ID']=='LG')].transpose()
# Out:
#                        0
# G_ID       20160401HHLG0
# GDAY_DS         20160401
# T_ID                  LG
# VS_T_ID               HH
# HEADER_NO              0
# TB_SC                  B
# PA                    47
# AB                    42
# RBI                    4
# RUN                    5
# HIT                    9
# H2                     2
# H3                     0
# HR                     1
# SB                     2
# CS                     1
# SH                     1
# SF                     0
# BB                     4
# IB                     0
# HP                     0
# KK                    11
# GD                     0
# ERR                    0
# LOB                    8
# P_HRA_RT        0.333333
# P_AB_CN               12
# P_HIT_CN               4

# %% [markdown]
# ## 팀투수

# %%
team_pitcher_2016.head(5).transpose()
# Out:
#                         0              1              2              3  \
# G_ID        20160401HHLG0  20160401HHLG0  20160401HTNC0  20160401HTNC0
# GDAY_DS          20160401       20160401       20160401       20160401
# T_ID                   LG             HH             NC             HT
# VS_T_ID                HH             LG             HT             NC
# HEADER_NO               0              0              0              0
# TB_SC                   B              T              B              T
# CG_CK                   0              0              0              0
# WLS                     W              L              W              L
# HOLD                    0              0              0              0
# INN2                   36             34             27             24
# BF                    184            196            143            147
# PA                     52             47             38             36
# AB                     46             42             34             30
# HIT                    13              9              8              9
# H2                      2              2              3              2
# H3                      0              0              0              0
# HR                      0              1              1              2
# SB                      0              2              0              0
# CS                      0              1              0              0
# SH                      3              1              0              1
# SF                      0              0              0              0
# BB                      3              4              3              5
# IB                      0              0              0              0
# HP                      0              0              1              0
# KK                     10             11             10              9
# GD                      1              0              1              1
# WP                      0              1              2              0
# BK                      0              0              0              0
# ERR                     0              0              0              0
# R                       4              5              4              5
# ER                      4              4              4              5
# P_WHIP_RT        0.642857            1.5        1.33333            0.5
# P2_WHIP_RT        1.28571              1        1.03846        1.69565
# CB_WHIP_RT            2.4           0.75        2.14286          1.875
#
#                         4
# G_ID        20160401KTSK0
# GDAY_DS          20160401
# T_ID                   SK
# VS_T_ID                KT
# HEADER_NO               0
# TB_SC                   B
# CG_CK                   0
# WLS                     L
# HOLD                    0
# INN2                   27
# BF                    151
# PA                     42
# AB                     36
# HIT                    11
# H2                      0
# H3                      0
# HR                      2
# SB                      2
# CS                      1
# SH                      0
# SF                      1
# BB                      4
# IB                      0
# HP                      1
# KK                      7
# GD                      0
# WP                      0
# BK                      0
# ERR                     0
# R                       8
# ER                      8
# P_WHIP_RT               1
# P2_WHIP_RT        2.35714
# CB_WHIP_RT           2.25
